# %% [markdown]
# <a href="https://colab.research.google.com/github/maps-05/elective_dataset/blob/main/PythonBasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: RELATIVO, MUFFLE P
# # Section: BSCPE III-GE

# %% [markdown]
# **Section 1: Phyton Environment SetUp**

# %%
# Activity: Online setup via Google collab

print("Hello, Love, Goodbye!")
# Out:
# Hello, Love, Goodbye!

# %%
 # Activity: Jupyter Notebook Overview

 print("THIS IS THE CODE CELL TO RUN PHYTON CODE")
# Out:
# THIS IS THE CODE CELL TO RUN PHYTON CODE

# %% [markdown]
# "THIS IS THE MARKDOWN CELL FOR EXPLANATIONS"

# %% [markdown]
# **Section 2: Phyton Basic - Part 1**

# %%
# Activity 1: Data types and variables

type(143)
# Out:
# int

# %%
type(1.43)
# Out:
# float

# %%
type("Maps")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# Part 2

# %%
# Activity 2: Printing in phyton (using f-string)

answer_1 = "Love"
answer_2 = "perceiving"
answer_3 = "trancends"
answer_4 = "space"
quotation = f"{answer_1} is the one thing we're capable of {answer_2} that {answer_3} dimension of time and {answer_4}."
print(quotation)
# Out:
# Love is the one thing we're capable of perceiving that trancends dimension of time and space.

# %%
# Activity 3: Data structures

# LIST
heroes = ["Miya", "Balmond", "Kadita"]
heroes.append("Gusion")
print (heroes)
# Out:
# ['Miya', 'Balmond', 'Kadita', 'Gusion']

# %%
# DICTIONARY

anime_list = {
    "Romcom" : "Oregairu",
    "Drama" : "Angel Beats",
    "Mystery" : "Your name",

}
romcom_anime = anime_list["Romcom"]
print("Romcom Anime:", romcom_anime)
# Out:
# Romcom Anime: Oregairu

# %%
#TUPLE

data = (50, 100)
print("Data:", data[1])
# Out:
# Data: 100

# %%
#SETS

even_numbers = {2, 4, 6, 8}
even_numbers.add(10)
print(even_numbers)
# Out:
# {2, 4, 6, 8, 10}

# %%
# Activity 4: Boolean values and operators

x = 1
y = 5

answer = (x > 0) and (y == 5)
print(answer)
# Out:
# True

# %%
# Activity 5: If statements and Loops

number = int(input("Please enter a number: "))

if number > 0:
    print("The number you entered is postive.")
elif number == 0:
    print("The number you entered is zero.")
else:
    print("The number you entered is negative.")
# Out:
# Please enter a number: 5
# The number you entered is postive.

# %%
# Loop through a list and range of numbers
integers = [100, 99, 98, 97, 96, 95]
for grade in integers:
    print(grade)

for tens in range(1, 10):
    print(tens)
# Out:
# 100
# 99
# 98
# 97
# 96
# 95
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
